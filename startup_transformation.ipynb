# %%
import codecademylib3
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# load in financial data
financial_data = pd.read_csv('financial_data.csv')

# code goes here
print(financial_data.head())

month = financial_data['Month']
revenue = financial_data['Revenue']
expenses = financial_data['Expenses']

# Plotting revenue over the past six months:
plt.plot(month,revenue)
plt.xlabel('Month')
plt.ylabel('Amount ($)')
plt.title('Revenue')
plt.show()

# Plotting expenses over the past six months:
plt.clf()
plt.plot(month,expenses)
plt.xlabel('Month')
plt.ylabel('Amount ($)')
plt.title('Expenses')
plt.show()

# Reading expenses.csv file:
expense_overview = pd.read_csv('expenses.csv')
print(expense_overview.head())

# Pie Chart and Collapsing Categories:
expense_categories = ['Salaries', 'Advertising', 'Office Rent', 'Other']
proportions = [0.62, 0.15, 0.15, 0.08]

# Creating a pie chart of the different expense categories:
plt.clf()
plt.pie(proportions, labels = expense_categories)
plt.axis('equal')
plt.tight_layout()
plt.show()

expense_cut = "Salaries"

# Employee Productivity:
#Loading the employees.csv file
employees = pd.read_csv('employees.csv')
print(employees.head())

# Sorting the employees dataFrame in ascending order by the productivity column:
sorted_productivity = employees.sort_values(by=['Productivity'])
print(sorted_productivity)

employees_cut = sorted_productivity.iloc[:100]
print(employees_cut)

transformation = "standardization"

# Commute Times and Log Transformation:
commute_times = employees["Commute Time"]
print(commute_times.describe())
commute_times_log = np.log(commute_times)

#Plotting Histogram of the commute time:
plt.clf()
plt.hist(commute_times_log)
plt.show()

# Extra:
salary_productivity_data = employees[["Salary", "Productivity"]]
print(salary_productivity_data)
scaler = StandardScaler()
standardized_data = scaler.fit_transform(salary_productivity_data)
df = pd.DataFrame(standardized_data, columns = ['Salary', 'Productivity'])
plt.clf()
df.plot(kind='bar', x="Salary", y="Productivity")
plt.show()
